# %%
# MODULE 6 CHALLENGE - PART 1
#  implement the feedback from the beta testers:
# - A weather description to the pop-up markers for customers so that they know what the weather is as they are traveling
# - A notation in the search criteria to indicate if it is raining or snowing for customers who are making travel decisions in real-time
# - A map that shows the directions for customers’ travel itinerary

# OBJECTIVES
# Use nested try-except blocks
# Use Pandas methods & attributes on a DF or Series
# Create a new DataFrame from a new API search with new weather parameters.
# Filter DataFrames based on input and nested decision statements, and logical expressions.
# Create pop-up markers on a Google map from a filtered DataFrame.
# Add a directions layer on a Google map between cities in the filtered DataFrame.

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library. 
# Run from terminal: - conda install -c conda-forge requests
import requests
#requests.__version__

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Part 1 Instructions
# Get the Weather Description and Amount of Precipitation for Each City

# 1. Create a new Jupyter Notebook file and name it Weather_Database.ipynb. - THIS FILE!!
# 2. Generate a new set of 1,500 random latitudes and longitudes.
# 3. Get the nearest city using the citipy module.
# 4. Perform an API call with the OpenWeatherMap.
# - Retrieve the following information from the API call:
# -- Latitude and longitude
# -- Maximum temperature
# -- Percent humidity
# -- Percent cloudiness
# -- Wind speed
# -- Weather description (e.g., clouds, fog, light rain, clear sky)
# -- The amount of rainfall over the last hour (1 hr).
# -- The amount of snowfall over the last hour (1 hr)
# 5. Try-except: Use multiple try-except blocks to get the amount of rainfall and snowfall. In the except block handle the KeyError if there is no rainfall or snowfall and add 0 inches for the amount.
# 6. Add the data to a new DataFrame.
# 7. Save the new DataFrame as a CSV file to be used for Part 2.
# 8. Upload the CSV file as part of your submission as WeatherPy_database.csv.

# %%
# 2. Generate a new set of 1,500 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
# Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# 3. Get the nearest city using the citipy module.
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Use the coordinates in our lat_lngs tuple to find the nearest city using Python’s citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
#print(cities)
#len(cities)

# %%
# 4. Perform an API call with the OpenWeatherMap.

# Starting URLs for Weather Map API Call.
city_base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
weather_base_url = "https://api.openweathermap.org/data/2.5/onecall?exclude=minutely,hourly,daily&appid="  + weather_api_key
#print(city_base_url)
#print(weather_base_url)

# - Retrieve the following information from the API call:
# -- Latitude and longitude
# -- Maximum temperature
# -- Percent humidity
# -- Percent cloudiness
# -- Wind speed
# -- Weather description (e.g., clouds, fog, light rain, clear sky)
# -- The amount of rainfall over the last hour (1 hr).
# -- The amount of snowfall over the last hour (1 hr)

# Create an empty list to hold the weather data.
city_weather_data = [] 
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
total_count = 0

# 5. Try-except: Use multiple try-except blocks to get the amount of rainfall and snowfall. In the except block handle the KeyError if there is no rainfall or snowfall and add 0 inches for the amount.
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    total_count += 1
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = city_base_url + "&q=" + city.replace(" ","+")
    #print(city_url)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Make the City API call, parse the JSON response (assuming you get the expected response) and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Weather description (e.g., clouds, fog, light rain, clear sky)
        # - Descrption is an ARRAY, may be more than one item, e.g. city_weather["weather"][0]["description"]
        # Reset a string to concatenate one or multiple 'description' strings.
        city_weather_desc = ''
        # Create a separator to distinguish between multiple descriptions.
        separator=''
        # Enumerate through the 'weather' array
        for idx, j in enumerate(city_weather["weather"]):
            # Add a comma if there is more than one description value.
            separator = '' if idx == 0 else ', '
            city_weather_desc = city_weather_desc + separator + j['description'] 
            #print (city_weather_desc)
        # amount of rainfall over the last hour (1 hr) - WHERE AVAILABLE!
        # amount of snowfall over the last hour (1 hr) - WHERE AVAILABLE!
        # Create endpoint URL for each city's lat's/long's.
        weather_url = weather_base_url + "&lat=" + str(city_lat) + "&lon=" + str(city_lng)
        #print(weather_url)
        # Make the Weather API call, parse the JSON response (assuming you get the expected response) and retrieve data.
        weather_forecast = requests.get(weather_url).json()
        #print(weather_forecast)
        try:
            current_rain = weather_forecast['current']['rain']['1h']
        except:
            current_rain = 0
        #print (current_rain)
        try:
            current_snow = weather_forecast['current']['snow']['1h']
        except:
            current_snow = 0
        #print (current_snow)
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city & weather information into city_weather_data list.

        # -- Latitude and longitude
        # -- Maximum temperature
        # -- Percent humidity
        # -- Percent cloudiness
        # -- Wind speed
        # -- Weather description (e.g., clouds, fog, light rain, clear sky)
        # -- The amount of rainfall over the last hour (1 hr).
        # -- The amount of snowfall over the last hour (1 hr)
        # Also include city & date for reference.
        city_weather_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Weather" : city_weather_desc,
            "Rain last hour": current_rain,
            "Snow last hour" : current_snow,
            "Date": city_date
        })

    # If an error is experienced, skip the city.
    except KeyError as e:
        print(f"Exception Type {type(e)}, {e}")
        print(f"City {city} not found. Skipping...")
        pass
    except Exception as e:
        print(f"Exception Type {type(e)}, {e}")
        print(f"City {city} OTHER EXCEPTION. RECHECK!!")
        pass
    
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print(f"Processed {total_count} records, {set_count} number of Sets")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | beba
# Processing Record 4 of Set 1 | marcona
# Exception Type <class 'KeyError'>, 'coord'
# City marcona not found. Skipping...
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | alice springs
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | doha
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | phichit
# Processing Record 14 of Set 1 | lompoc
# Processing Record 15 of Set 1 | grand river south east
# Exception Type <class 'KeyError'>, 'coord'
# City grand river south east not found. Skipping...
# Processing Record 16 of Set 1 | paikuse
# Processing Record 17 of Set 1 | ravar
# Processing Record 18 of Set 1 | muscat
# Processing Record 19 of Set 1 | bridlington
# Processing Record 20 of Set 1 | novopavlovka
# Processing Record 21 of Set 1 | san quintin
# Processing Record 22 of Set 1 | vagur
# Processing Record 23 of Set 1 | nioro
# Processing Record 24 of Set 1 | broome
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | praia
# Processing Record 29 of Set 1 | algiers
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | taolanaro
# Exception Type <class 'KeyError'>, 'coord'
# City taolanaro not found. Skipping...
# Processing Record 33 of Set 1 | mattru
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | bilibino
# Processing Record 36 of Set 1 | leh
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | boa vista
# Processing Record 40 of Set 1 | idrinskoye
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | maniitsoq
# Processing Record 43 of Set 1 | kangaatsiaq
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | oda
# Processing Record 46 of Set 1 | zhuanghe
# Processing Record 47 of Set 1 | iquique
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | bristol
# Processing Record 2 of Set 2 | touros
# Processing Record 3 of Set 2 | vangaindrano
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | chernyy yar
# Processing Record 7 of Set 2 | katsuura
# Processing Record 8 of Set 2 | elliot lake
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | halifax
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | amderma
# Exception Type <class 'KeyError'>, 'coord'
# City amderma not found. Skipping...
# Processing Record 13 of Set 2 | karatau
# Processing Record 14 of Set 2 | padang
# Processing Record 15 of Set 2 | aurillac
# Processing Record 16 of Set 2 | moussoro
# Processing Record 17 of Set 2 | ketchikan
# Processing Record 18 of Set 2 | santa engracia
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | puerto del rosario
# Processing Record 21 of Set 2 | asau
# Processing Record 22 of Set 2 | kabirwala
# Processing Record 23 of Set 2 | novyy nekouz
# Processing Record 24 of Set 2 | saint-augustin
# Processing Record 25 of Set 2 | coffs harbour
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | santa marta
# Processing Record 28 of Set 2 | severo-kurilsk
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | high prairie
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | saint-pierre
# Processing Record 36 of Set 2 | high level
# Processing Record 37 of Set 2 | prince rupert
# Processing Record 38 of Set 2 | lata
# Processing Record 39 of Set 2 | pangnirtung
# Processing Record 40 of Set 2 | faya
# Processing Record 41 of Set 2 | point pedro
# Processing Record 42 of Set 2 | staryy nadym
# Processing Record 43 of Set 2 | san patricio
# Processing Record 44 of Set 2 | smithers
# Processing Record 45 of Set 2 | abeche
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | saleaula
# Exception Type <class 'KeyError'>, 'coord'
# City saleaula not found. Skipping...
# Processing Record 48 of Set 2 | santa maria
# Processing Record 49 of Set 2 | aja
# Processing Record 50 of Set 2 | constitucion
# Processing Record 1 of Set 3 | kahului
# Processing Record 2 of Set 3 | morondava
# Processing Record 3 of Set 3 | port macquarie
# Processing Record 4 of Set 3 | skiros
# Exception Type <class 'KeyError'>, 'coord'
# City skiros not found. Skipping...
# Processing Record 5 of Set 3 | te anau
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | huilong
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | kon tum
# Processing Record 10 of Set 3 | san policarpo
# Processing Record 11 of Set 3 | marawi
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | rawannawi
# Exception Type <class 'KeyError'>, 'coord'
# City rawannawi not found. Skipping...
# Processing Record 15 of Set 3 | usinsk
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | maarianhamina
# Processing Record 18 of Set 3 | lipin bor
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | port hardy
# Processing Record 21 of Set 3 | barentsburg
# Exception Type <class 'KeyError'>, 'coord'
# City barentsburg not found. Skipping...
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | bereda
# Processing Record 24 of Set 3 | yurya
# Exception Type <class 'KeyError'>, 'coord'
# City yurya not found. Skipping...
# Processing Record 25 of Set 3 | isfana
# Processing Record 26 of Set 3 | longlac
# Exception Type <class 'KeyError'>, 'coord'
# City longlac not found. Skipping...
# Processing Record 27 of Set 3 | metro
# Processing Record 28 of Set 3 | andilamena
# Processing Record 29 of Set 3 | kavieng
# Processing Record 30 of Set 3 | jiana
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | westport
# Processing Record 33 of Set 3 | zalantun
# Processing Record 34 of Set 3 | chimbote
# Processing Record 35 of Set 3 | parati
# Processing Record 36 of Set 3 | nelson bay
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | santa eulalia del rio
# Exception Type <class 'KeyError'>, 'coord'
# City santa eulalia del rio not found. Skipping...
# Processing Record 39 of Set 3 | nhulunbuy
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | semey
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | riyadh
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | chardara
# Processing Record 47 of Set 3 | belushya guba
# Exception Type <class 'KeyError'>, 'coord'
# City belushya guba not found. Skipping...
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | atar
# Processing Record 50 of Set 3 | shu
# Processing Record 1 of Set 4 | cape town
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | lolua
# Exception Type <class 'KeyError'>, 'coord'
# City lolua not found. Skipping...
# Processing Record 4 of Set 4 | taltal
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | ayer itam
# Exception Type <class 'KeyError'>, 'coord'
# City ayer itam not found. Skipping...
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | tibiri
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | arraial do cabo
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | shingu
# Processing Record 13 of Set 4 | verkhnyaya inta
# Processing Record 14 of Set 4 | barahona
# Processing Record 15 of Set 4 | dolbeau
# Exception Type <class 'KeyError'>, 'coord'
# City dolbeau not found. Skipping...
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | sentyabrskiy
# Exception Type <class 'KeyError'>, 'coord'
# City sentyabrskiy not found. Skipping...
# Processing Record 19 of Set 4 | coruripe
# Processing Record 20 of Set 4 | kamenskoye
# Exception Type <class 'KeyError'>, 'coord'
# City kamenskoye not found. Skipping...
# Processing Record 21 of Set 4 | kindu
# Processing Record 22 of Set 4 | acatlan
# Processing Record 23 of Set 4 | kazalinsk
# Exception Type <class 'KeyError'>, 'coord'
# City kazalinsk not found. Skipping...
# Processing Record 24 of Set 4 | ankazoabo
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | dongsheng
# Processing Record 27 of Set 4 | hoa binh
# Processing Record 28 of Set 4 | tautira
# Processing Record 29 of Set 4 | tabialan
# Exception Type <class 'KeyError'>, 'coord'
# City tabialan not found. Skipping...
# Processing Record 30 of Set 4 | itarema
# Processing Record 31 of Set 4 | florence
# Processing Record 32 of Set 4 | bethel
# Processing Record 33 of Set 4 | sur
# Processing Record 34 of Set 4 | moche
# Processing Record 35 of Set 4 | barrow
# Processing Record 36 of Set 4 | hunza
# Exception Type <class 'KeyError'>, 'coord'
# City hunza not found. Skipping...
# Processing Record 37 of Set 4 | nola
# Processing Record 38 of Set 4 | tete
# Processing Record 39 of Set 4 | scarborough
# Processing Record 40 of Set 4 | ambon
# Processing Record 41 of Set 4 | illoqqortoormiut
# Exception Type <class 'KeyError'>, 'coord'
# City illoqqortoormiut not found. Skipping...
# Processing Record 42 of Set 4 | abengourou
# Processing Record 43 of Set 4 | beauceville
# Processing Record 44 of Set 4 | hokitika
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | tabou
# Processing Record 49 of Set 4 | pacific grove
# Processing Record 50 of Set 4 | nizhneyansk
# Exception Type <class 'KeyError'>, 'coord'
# City nizhneyansk not found. Skipping...
# Processing Record 1 of Set 5 | pottsville
# Processing Record 2 of Set 5 | sinnamary
# Processing Record 3 of Set 5 | waterloo
# Processing Record 4 of Set 5 | pauini
# Processing Record 5 of Set 5 | marsh harbour
# Processing Record 6 of Set 5 | kiambu
# Processing Record 7 of Set 5 | smidovich
# Processing Record 8 of Set 5 | yumen
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | zaragoza
# Processing Record 12 of Set 5 | northam
# Processing Record 13 of Set 5 | port blair
# Processing Record 14 of Set 5 | oranjemund
# Processing Record 15 of Set 5 | chokurdakh
# Processing Record 16 of Set 5 | erenhot
# Processing Record 17 of Set 5 | flinders
# Processing Record 18 of Set 5 | lavrentiya
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | lethem
# Processing Record 21 of Set 5 | san jeronimo
# Processing Record 22 of Set 5 | soyo
# Processing Record 23 of Set 5 | tumannyy
# Exception Type <class 'KeyError'>, 'coord'
# City tumannyy not found. Skipping...
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | stonewall
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | naze
# Processing Record 29 of Set 5 | chabahar
# Processing Record 30 of Set 5 | tunduru
# Exception Type <class 'KeyError'>, 'coord'
# City tunduru not found. Skipping...
# Processing Record 31 of Set 5 | guastalla
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | sarkand
# Processing Record 34 of Set 5 | soto la marina
# Processing Record 35 of Set 5 | buala
# Processing Record 36 of Set 5 | black river
# Processing Record 37 of Set 5 | north platte
# Processing Record 38 of Set 5 | kattivakkam
# Processing Record 39 of Set 5 | srednekolymsk
# Processing Record 40 of Set 5 | maniwaki
# Processing Record 41 of Set 5 | longyearbyen
# Processing Record 42 of Set 5 | russell
# Processing Record 43 of Set 5 | metehara
# Exception Type <class 'KeyError'>, 'coord'
# City metehara not found. Skipping...
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | tsihombe
# Exception Type <class 'KeyError'>, 'coord'
# City tsihombe not found. Skipping...
# Processing Record 46 of Set 5 | dubai
# Processing Record 47 of Set 5 | horovice
# Processing Record 48 of Set 5 | noumea
# Processing Record 49 of Set 5 | sao gabriel da cachoeira
# Processing Record 50 of Set 5 | maningrida
# Processing Record 1 of Set 6 | haysville
# Processing Record 2 of Set 6 | usak
# Processing Record 3 of Set 6 | trebisacce
# Processing Record 4 of Set 6 | hihifo
# Exception Type <class 'KeyError'>, 'coord'
# City hihifo not found. Skipping...
# Processing Record 5 of Set 6 | billings
# Processing Record 6 of Set 6 | harper
# Processing Record 7 of Set 6 | paamiut
# Processing Record 8 of Set 6 | general cepeda
# Processing Record 9 of Set 6 | xiangdong
# Exception Type <class 'KeyError'>, 'coord'
# City xiangdong not found. Skipping...
# Processing Record 10 of Set 6 | vaitupu
# Exception Type <class 'KeyError'>, 'coord'
# City vaitupu not found. Skipping...
# Processing Record 11 of Set 6 | butaritari
# Processing Record 12 of Set 6 | thompson
# Processing Record 13 of Set 6 | margate
# Processing Record 14 of Set 6 | mys shmidta
# Exception Type <class 'KeyError'>, 'coord'
# City mys shmidta not found. Skipping...
# Processing Record 15 of Set 6 | revda
# Processing Record 16 of Set 6 | novoagansk
# Processing Record 17 of Set 6 | waipawa
# Processing Record 18 of Set 6 | kaeo
# Processing Record 19 of Set 6 | samusu
# Exception Type <class 'KeyError'>, 'coord'
# City samusu not found. Skipping...
# Processing Record 20 of Set 6 | concordia
# Processing Record 21 of Set 6 | luganville
# Processing Record 22 of Set 6 | nizhniy ingash
# Processing Record 23 of Set 6 | pocone
# Processing Record 24 of Set 6 | nawa
# Processing Record 25 of Set 6 | provideniya
# Processing Record 26 of Set 6 | evensk
# Processing Record 27 of Set 6 | bitung
# Processing Record 28 of Set 6 | port hedland
# Processing Record 29 of Set 6 | bowling green
# Processing Record 30 of Set 6 | peniche
# Processing Record 31 of Set 6 | leningradskiy
# Processing Record 32 of Set 6 | bengkulu
# Processing Record 33 of Set 6 | cockburn town
# Processing Record 34 of Set 6 | medea
# Processing Record 35 of Set 6 | francisco sa
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | tiznit
# Processing Record 38 of Set 6 | thinadhoo
# Processing Record 39 of Set 6 | antofagasta
# Processing Record 40 of Set 6 | avera
# Processing Record 41 of Set 6 | panguna
# Processing Record 42 of Set 6 | marsa matruh
# Processing Record 43 of Set 6 | sola
# Processing Record 44 of Set 6 | jumla
# Processing Record 45 of Set 6 | kununurra
# Processing Record 46 of Set 6 | sarh
# Processing Record 47 of Set 6 | beira
# Processing Record 48 of Set 6 | chipinge
# Processing Record 49 of Set 6 | hammerfest
# Processing Record 50 of Set 6 | toliary
# Exception Type <class 'KeyError'>, 'coord'
# City toliary not found. Skipping...
# Processing Record 1 of Set 7 | bathsheba
# Processing Record 2 of Set 7 | kismayo
# Processing Record 3 of Set 7 | sudak
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | nantucket
# Processing Record 6 of Set 7 | abdanan
# Processing Record 7 of Set 7 | micheweni
# Processing Record 8 of Set 7 | kanigiri
# Processing Record 9 of Set 7 | mundo nuevo
# Processing Record 10 of Set 7 | dvinskoy
# Processing Record 11 of Set 7 | loandjili
# Processing Record 12 of Set 7 | mendahara
# Exception Type <class 'KeyError'>, 'coord'
# City mendahara not found. Skipping...
# Processing Record 13 of Set 7 | casablanca
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | salta
# Processing Record 16 of Set 7 | mweka
# Processing Record 17 of Set 7 | gat
# Processing Record 18 of Set 7 | cukai
# Processing Record 19 of Set 7 | north bend
# Processing Record 20 of Set 7 | goundi
# Processing Record 21 of Set 7 | cabo san lucas
# Processing Record 22 of Set 7 | shchigry
# Processing Record 23 of Set 7 | roma
# Processing Record 24 of Set 7 | stolin
# Processing Record 25 of Set 7 | manavalakurichi
# Processing Record 26 of Set 7 | yermakovskoye
# Processing Record 27 of Set 7 | vesele
# Processing Record 28 of Set 7 | rungata
# Exception Type <class 'KeyError'>, 'coord'
# City rungata not found. Skipping...
# Processing Record 29 of Set 7 | okha
# Processing Record 30 of Set 7 | pandharpur
# Processing Record 31 of Set 7 | katobu
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | rafsanjan
# Processing Record 34 of Set 7 | grindavik
# Processing Record 35 of Set 7 | pevek
# Processing Record 36 of Set 7 | kudahuvadhoo
# Processing Record 37 of Set 7 | senanga
# Processing Record 38 of Set 7 | westpunt
# Exception Type <class 'KeyError'>, 'coord'
# City westpunt not found. Skipping...
# Processing Record 39 of Set 7 | saldanha
# Processing Record 40 of Set 7 | cache creek
# Processing Record 41 of Set 7 | juegang
# Processing Record 42 of Set 7 | yerbogachen
# Processing Record 43 of Set 7 | zaysan
# Processing Record 44 of Set 7 | grand gaube
# Processing Record 45 of Set 7 | kochevo
# Processing Record 46 of Set 7 | namibe
# Processing Record 47 of Set 7 | genhe
# Processing Record 48 of Set 7 | hambantota
# Processing Record 49 of Set 7 | archidona
# Processing Record 50 of Set 7 | kupino
# Processing Record 1 of Set 8 | batagay-alyta
# Processing Record 2 of Set 8 | llangefni
# Processing Record 3 of Set 8 | pio xii
# Processing Record 4 of Set 8 | sangar
# Processing Record 5 of Set 8 | ereymentau
# Processing Record 6 of Set 8 | tsiroanomandidy
# Processing Record 7 of Set 8 | manuk mangkaw
# Processing Record 8 of Set 8 | ferkessedougou
# Processing Record 9 of Set 8 | ambodifototra
# Exception Type <class 'KeyError'>, 'coord'
# City ambodifototra not found. Skipping...
# Processing Record 10 of Set 8 | hualmay
# Processing Record 11 of Set 8 | vardo
# Processing Record 12 of Set 8 | maragogi
# Processing Record 13 of Set 8 | blagoyevo
# Processing Record 14 of Set 8 | beisfjord
# Processing Record 15 of Set 8 | daru
# Processing Record 16 of Set 8 | mariakani
# Processing Record 17 of Set 8 | lasa
# Processing Record 18 of Set 8 | stoyba
# Exception Type <class 'KeyError'>, 'coord'
# City stoyba not found. Skipping...
# Processing Record 19 of Set 8 | coquimbo
# Processing Record 20 of Set 8 | muros
# Processing Record 21 of Set 8 | indianola
# Processing Record 22 of Set 8 | veraval
# Processing Record 23 of Set 8 | karratha
# Processing Record 24 of Set 8 | zhitikara
# Exception Type <class 'KeyError'>, 'coord'
# City zhitikara not found. Skipping...
# Processing Record 25 of Set 8 | tessalit
# Processing Record 26 of Set 8 | kalmunai
# Processing Record 27 of Set 8 | caracollo
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | kiruna
# Processing Record 30 of Set 8 | hima
# Processing Record 31 of Set 8 | honningsvag
# Processing Record 32 of Set 8 | champerico
# Processing Record 33 of Set 8 | portland
# Processing Record 34 of Set 8 | riohacha
# Processing Record 35 of Set 8 | bilma
# Processing Record 36 of Set 8 | ust-tsilma
# Processing Record 37 of Set 8 | mungwi
# Processing Record 38 of Set 8 | qala
# Processing Record 39 of Set 8 | san luis
# Processing Record 40 of Set 8 | castro
# Processing Record 41 of Set 8 | darhan
# Processing Record 42 of Set 8 | lagoa
# Processing Record 43 of Set 8 | hovd
# Processing Record 44 of Set 8 | hushitai
# Processing Record 45 of Set 8 | yankton
# Processing Record 46 of Set 8 | biak
# Processing Record 47 of Set 8 | kadoma
# Processing Record 48 of Set 8 | ocampo
# Processing Record 49 of Set 8 | ahipara
# Processing Record 50 of Set 8 | pangoa
# Processing Record 1 of Set 9 | hailun
# Processing Record 2 of Set 9 | victoria
# Processing Record 3 of Set 9 | skalistyy
# Exception Type <class 'KeyError'>, 'coord'
# City skalistyy not found. Skipping...
# Processing Record 4 of Set 9 | ahuimanu
# Processing Record 5 of Set 9 | providencia
# Processing Record 6 of Set 9 | allonnes
# Processing Record 7 of Set 9 | kamaishi
# Processing Record 8 of Set 9 | jizan
# Processing Record 9 of Set 9 | mount gambier
# Processing Record 10 of Set 9 | seguela
# Processing Record 11 of Set 9 | qidong
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | urucara
# Processing Record 14 of Set 9 | sebeta
# Processing Record 15 of Set 9 | menongue
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | mildura
# Processing Record 18 of Set 9 | nalut
# Processing Record 19 of Set 9 | tukrah
# Processing Record 20 of Set 9 | puerto escondido
# Processing Record 21 of Set 9 | abha
# Processing Record 22 of Set 9 | port lincoln
# Processing Record 23 of Set 9 | makakilo city
# Processing Record 24 of Set 9 | tornio
# Processing Record 25 of Set 9 | umzimvubu
# Exception Type <class 'KeyError'>, 'coord'
# City umzimvubu not found. Skipping...
# Processing Record 26 of Set 9 | shuyskoye
# Processing Record 27 of Set 9 | attawapiskat
# Exception Type <class 'KeyError'>, 'coord'
# City attawapiskat not found. Skipping...
# Processing Record 28 of Set 9 | burns lake
# Processing Record 29 of Set 9 | mayskiy
# Processing Record 30 of Set 9 | zhangye
# Processing Record 31 of Set 9 | kijang
# Processing Record 32 of Set 9 | hamilton
# Processing Record 33 of Set 9 | sao felix do xingu
# Processing Record 34 of Set 9 | kinablangan
# Processing Record 35 of Set 9 | hasaki
# Processing Record 36 of Set 9 | olafsvik
# Processing Record 37 of Set 9 | bolungarvik
# Exception Type <class 'KeyError'>, 'coord'
# City bolungarvik not found. Skipping...
# Processing Record 38 of Set 9 | kieta
# Processing Record 39 of Set 9 | belmonte
# Processing Record 40 of Set 9 | dhidhdhoo
# Processing Record 41 of Set 9 | saint anthony
# Processing Record 42 of Set 9 | mahebourg
# Processing Record 43 of Set 9 | libertador general san martin
# Processing Record 44 of Set 9 | nouadhibou
# Processing Record 45 of Set 9 | abu zabad
# Processing Record 46 of Set 9 | bonthe
# Processing Record 47 of Set 9 | clarence town
# Processing Record 48 of Set 9 | samalaeulu
# Exception Type <class 'KeyError'>, 'coord'
# City samalaeulu not found. Skipping...
# Processing Record 49 of Set 9 | pontianak
# Processing Record 50 of Set 9 | rakai
# Processing Record 1 of Set 10 | tual
# Processing Record 2 of Set 10 | banda aceh
# Processing Record 3 of Set 10 | ancud
# Processing Record 4 of Set 10 | mao
# Processing Record 5 of Set 10 | mercogliano
# Processing Record 6 of Set 10 | ponta do sol
# Processing Record 7 of Set 10 | diffa
# Processing Record 8 of Set 10 | aqtobe
# Processing Record 9 of Set 10 | inhambane
# Processing Record 10 of Set 10 | ponta delgada
# Processing Record 11 of Set 10 | fairbanks
# Processing Record 12 of Set 10 | tawau
# Processing Record 13 of Set 10 | azimur
# Exception Type <class 'KeyError'>, 'coord'
# City azimur not found. Skipping...
# Processing Record 14 of Set 10 | adrar
# Processing Record 15 of Set 10 | los llanos de aridane
# Processing Record 16 of Set 10 | sibu
# Processing Record 17 of Set 10 | sekoma
# Processing Record 18 of Set 10 | sept-iles
# Processing Record 19 of Set 10 | morgan city
# Processing Record 20 of Set 10 | qinzhou
# Processing Record 21 of Set 10 | general roca
# Processing Record 22 of Set 10 | saint george
# Processing Record 23 of Set 10 | chagda
# Exception Type <class 'KeyError'>, 'coord'
# City chagda not found. Skipping...
# Processing Record 24 of Set 10 | saint-georges
# Processing Record 25 of Set 10 | guastatoya
# Processing Record 26 of Set 10 | chico
# Processing Record 27 of Set 10 | santiago del estero
# Processing Record 28 of Set 10 | gayny
# Processing Record 29 of Set 10 | paombong
# Processing Record 30 of Set 10 | millinocket
# Processing Record 31 of Set 10 | cururupu
# Processing Record 32 of Set 10 | zyryanka
# Processing Record 33 of Set 10 | talnakh
# Processing Record 34 of Set 10 | namtsy
# Processing Record 35 of Set 10 | arman
# Processing Record 36 of Set 10 | ous
# Processing Record 37 of Set 10 | lhuntshi
# Exception Type <class 'KeyError'>, 'coord'
# City lhuntshi not found. Skipping...
# Processing Record 38 of Set 10 | annur
# Processing Record 39 of Set 10 | sembabule
# Processing Record 40 of Set 10 | korla
# Processing Record 41 of Set 10 | acari
# Processing Record 42 of Set 10 | kragujevac
# Processing Record 43 of Set 10 | alexandria
# Processing Record 44 of Set 10 | lumphat
# Processing Record 45 of Set 10 | dunedin
# Processing Record 46 of Set 10 | vavuniya
# Processing Record 47 of Set 10 | fort nelson
# Processing Record 48 of Set 10 | bodden town
# Processing Record 49 of Set 10 | polyanka
# Processing Record 50 of Set 10 | xiongzhou
# Processing Record 1 of Set 11 | tabiauea
# Exception Type <class 'KeyError'>, 'coord'
# City tabiauea not found. Skipping...
# Processing Record 2 of Set 11 | kemijarvi
# Processing Record 3 of Set 11 | tateyama
# Processing Record 4 of Set 11 | bekhtery
# Processing Record 5 of Set 11 | ust-kamchatsk
# Exception Type <class 'KeyError'>, 'coord'
# City ust-kamchatsk not found. Skipping...
# Processing Record 6 of Set 11 | tilichiki
# Processing Record 7 of Set 11 | richards bay
# Processing Record 8 of Set 11 | bardiyah
# Processing Record 9 of Set 11 | anadyr
# Processing Record 10 of Set 11 | sabang
# Processing Record 11 of Set 11 | clyde river
# Processing Record 12 of Set 11 | yangjiang
# Processing Record 13 of Set 11 | koslan
# Processing Record 14 of Set 11 | gazanjyk
# Processing Record 15 of Set 11 | auki
# Processing Record 16 of Set 11 | ternate
# Processing Record 17 of Set 11 | sug-aksy
# Exception Type <class 'KeyError'>, 'coord'
# City sug-aksy not found. Skipping...
# Processing Record 18 of Set 11 | noyabrsk
# Processing Record 19 of Set 11 | raudeberg
# Processing Record 20 of Set 11 | popondetta
# Processing Record 21 of Set 11 | sechura
# Processing Record 22 of Set 11 | lishu
# Processing Record 23 of Set 11 | catuday
# Processing Record 24 of Set 11 | jasrana
# Processing Record 25 of Set 11 | bollnas
# Processing Record 26 of Set 11 | caibarien
# Processing Record 27 of Set 11 | calama
# Processing Record 28 of Set 11 | san cristobal
# Processing Record 29 of Set 11 | shimoda
# Processing Record 30 of Set 11 | nome
# Processing Record 31 of Set 11 | bandar-e anzali
# Processing Record 32 of Set 11 | nuuk
# Processing Record 33 of Set 11 | porto novo
# Processing Record 34 of Set 11 | wanning
# Processing Record 35 of Set 11 | sioux lookout
# Processing Record 36 of Set 11 | bundaberg
# Processing Record 37 of Set 11 | christchurch
# Processing Record 38 of Set 11 | novo aripuana
# Processing Record 39 of Set 11 | matameye
# Exception Type <class 'KeyError'>, 'coord'
# City matameye not found. Skipping...
# Processing Record 40 of Set 11 | seybaplaya
# Processing Record 41 of Set 11 | buchanan
# Processing Record 42 of Set 11 | maralal
# Processing Record 43 of Set 11 | kaitangata
# Processing Record 44 of Set 11 | lieksa
# Processing Record 45 of Set 11 | bela
# Processing Record 46 of Set 11 | grand-santi
# Processing Record 47 of Set 11 | somerset
# Processing Record 48 of Set 11 | kenai
# Processing Record 49 of Set 11 | haines junction
# Processing Record 50 of Set 11 | viligili
# Exception Type <class 'KeyError'>, 'coord'
# City viligili not found. Skipping...
# Processing Record 1 of Set 12 | tagudin
# Processing Record 2 of Set 12 | sorong
# Processing Record 3 of Set 12 | aberdeen
# Processing Record 4 of Set 12 | komsomolskiy
# Processing Record 5 of Set 12 | saint-philippe
# Processing Record 6 of Set 12 | racovita
# Processing Record 7 of Set 12 | tecoanapa
# Processing Record 8 of Set 12 | iqaluit
# Processing Record 9 of Set 12 | muroto
# Processing Record 10 of Set 12 | nichinan
# Processing Record 11 of Set 12 | black forest
# Processing Record 12 of Set 12 | djougou
# Processing Record 13 of Set 12 | betioky
# Processing Record 14 of Set 12 | camapua
# Processing Record 15 of Set 12 | gamba
# Processing Record 16 of Set 12 | khimki
# Processing Record 17 of Set 12 | mondlo
# Processing Record 18 of Set 12 | maldonado
# Processing Record 19 of Set 12 | batsfjord
# Processing Record 20 of Set 12 | seoul
# Processing Record 21 of Set 12 | fairview
# Processing Record 22 of Set 12 | bayburt
# Processing Record 23 of Set 12 | pakxan
# Processing Record 24 of Set 12 | swift current
# Processing Record 25 of Set 12 | bani walid
# Processing Record 26 of Set 12 | la paz
# Processing Record 27 of Set 12 | linda
# Processing Record 28 of Set 12 | vina del mar
# Processing Record 29 of Set 12 | anao
# Processing Record 30 of Set 12 | mareeba
# Processing Record 31 of Set 12 | labuhan
# Processing Record 32 of Set 12 | samarai
# Processing Record 33 of Set 12 | gravdal
# Processing Record 34 of Set 12 | robore
# Processing Record 35 of Set 12 | kongolo
# Processing Record 36 of Set 12 | zhirnovsk
# Processing Record 37 of Set 12 | san vicente
# Processing Record 38 of Set 12 | khilok
# Processing Record 39 of Set 12 | umm kaddadah
# Processing Record 40 of Set 12 | passo de camaragibe
# Processing Record 41 of Set 12 | vallenar
# Processing Record 42 of Set 12 | brae
# Processing Record 43 of Set 12 | soeng sang
# Processing Record 44 of Set 12 | yunjinghong
# Exception Type <class 'KeyError'>, 'coord'
# City yunjinghong not found. Skipping...
# Processing Record 45 of Set 12 | yeniseysk
# Processing Record 46 of Set 12 | songjianghe
# Processing Record 47 of Set 12 | powell
# Processing Record 48 of Set 12 | turka
# Processing Record 49 of Set 12 | timbiqui
# Processing Record 50 of Set 12 | kifri
# Processing Record 1 of Set 13 | nauta
# Processing Record 2 of Set 13 | mont-dore
# Processing Record 3 of Set 13 | novyy urengoy
# Processing Record 4 of Set 13 | berlevag
# Processing Record 5 of Set 13 | pochutla
# Processing Record 6 of Set 13 | okhotsk
# Processing Record 7 of Set 13 | kandrian
# Processing Record 8 of Set 13 | agadir
# Processing Record 9 of Set 13 | tuggurt
# Exception Type <class 'KeyError'>, 'coord'
# City tuggurt not found. Skipping...
# Processing Record 10 of Set 13 | zunyi
# Processing Record 11 of Set 13 | biltine
# Processing Record 12 of Set 13 | qasigiannguit
# Processing Record 13 of Set 13 | manaus
# Processing Record 14 of Set 13 | nadym
# Processing Record 15 of Set 13 | peplos
# Processing Record 16 of Set 13 | chumikan
# Processing Record 17 of Set 13 | eldorado
# Processing Record 18 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 13 | dauphin
# Processing Record 20 of Set 13 | ugoofaaru
# Processing Record 21 of Set 13 | victoria point
# Processing Record 22 of Set 13 | vila
# Processing Record 23 of Set 13 | scalloway
# Exception Type <class 'KeyError'>, 'coord'
# City scalloway not found. Skipping...
# Processing Record 24 of Set 13 | olenegorsk
# Processing Record 25 of Set 13 | dire dawa
# Processing Record 26 of Set 13 | ganzhou
# Processing Record 27 of Set 13 | pontes e lacerda
# Processing Record 28 of Set 13 | obera
# Processing Record 29 of Set 13 | ratnagiri
# Processing Record 30 of Set 13 | turayf
# Processing Record 31 of Set 13 | bonanza
# Processing Record 32 of Set 13 | nargana
# Processing Record 33 of Set 13 | niort
# Processing Record 34 of Set 13 | la rioja
# Processing Record 35 of Set 13 | tabukiniberu
# Exception Type <class 'KeyError'>, 'coord'
# City tabukiniberu not found. Skipping...
# Processing Record 36 of Set 13 | takaka
# Processing Record 37 of Set 13 | whitehorse
# Processing Record 38 of Set 13 | fevralsk
# Exception Type <class 'KeyError'>, 'coord'
# City fevralsk not found. Skipping...
# Processing Record 39 of Set 13 | shubarshi
# Processing Record 40 of Set 13 | karaul
# Exception Type <class 'KeyError'>, 'coord'
# City karaul not found. Skipping...
# Processing Record 41 of Set 13 | carutapera
# Processing Record 42 of Set 13 | beringovskiy
# Processing Record 43 of Set 13 | laguna
# Processing Record 44 of Set 13 | kidal
# Processing Record 45 of Set 13 | imbituba
# Processing Record 46 of Set 13 | moron
# Processing Record 47 of Set 13 | whitianga
# Processing Record 48 of Set 13 | basco
# -----------------------------
# Processed 648 records, 13 number of Sets
# Data Retrieval Complete
# -----------------------------

# %%
# 6. Add the data to a new DataFrame.
city_weather_data_df=pd.DataFrame(city_weather_data)

# %%
# From "Module 6-Detailed-Rubric-Python-API_online_rubric-1.pdf"
## ✓ Use Pandas to correctly answer this question: 
### How many cities have recorded rainfall or snow?
print ((city_weather_data_df.loc[city_weather_data_df['Rain last hour'] > 0].count()))
print ((city_weather_data_df.loc[city_weather_data_df['Snow last hour'] > 0].count()))
# Out:
# City              70
# Lat               70
# Lng               70
# Max Temp          70
# Humidity          70
# Cloudiness        70
# Wind Speed        70
# Country           70
# Weather           70
# Rain last hour    70
# Snow last hour    70
# Date              70
# dtype: int64
# City              0
# Lat               0
# Lng               0
# Max Temp          0
# Humidity          0
# Cloudiness        0
# Wind Speed        0
# Country           0
# Weather           0
# Rain last hour    0
# Snow last hour    0
# Date              0
# dtype: int64

# %%
# 7. Save the new DataFrame as a CSV file to be used for Part 2.
# Create the output file (CSV).
output_data_file = "weather_data/cities_weather.csv"
# Export the city_weather_data into a CSV.
city_weather_data_df.to_csv(output_data_file, index_label="City_ID")

# 8. Upload the CSV file as part of your submission as WeatherPy_database.csv.
# - DONE, see https://github.com/damiencorr/World_Weather_Analysis/tree/master/weather_data
